# %% [markdown]
# Importation des bibliothèques

# %%
import pandas as pd

# %% [markdown]
# Constante

# %%
# chemin pour accéder aux données
FILE_PATH = '../src/data/donnees_immobilieres.parquet'

# %% [markdown]
# Application

# %% [markdown]
# | Nom de colonne                 | Description |
# |--------------------------------|-------------|
# | region                         | Région où se situe le bien |
# | ue                             | Identifiant de l’Unité économique (Site). À compter du 31/10/2015, remplacé par l’ID unique du bien |
# | id                             | Identifiant unique du bien |
# | type                           | Usage majoritaire du bien |
# | fonction                       | Usage majoritaire détaillé du bien |
# | designation_batiment_terrain   | Désignation du bâtiment ou terrain |
# | dept                           | Code du département de situation du bien |
# | adresse                        | Adresse normalisée du bien |
# | code_postal                    | Code postal de situation du bien |
# | ville                          | Ville de situation du bien |
# | pays                           | Pays de situation du bien |
# | ministere                      | Ministère occupant le bien |
# | date_inventaire                | Date de l’inventaire |

# %%
# Chargement du DataFrame depuis le fichier Parquet 
df = pd.read_parquet(FILE_PATH)

# %%
df.head()
# Out:
#                region                                ue  \
# 0               CORSE  a19e7cbea4c2dae3cfca703bda49e466
# 1  NORD-PAS DE CALAIS  c1fb47969da8dd1a5a1a93ae33245ced
# 2       ILE DE France                            120994
# 3         RHONE ALPES                            152769
# 4     BASSE NORMANDIE                            126681
#
#                                  id                               type  \
# 0  936465ba5b332c60491f6cba50a76b49  biens du ministère de l'Intérieur
# 1  44b7ec415ee6f810d44fda9c8c585069  biens du ministère de l'Intérieur
# 2                     IG00100036786                     Espace naturel
# 3                     IB00100093449                 Bâtiment technique
# 4                     IB00100205180                 Bâtiment technique
#
#                             fonction  \
# 0  biens du ministère de l'Intérieur
# 1  biens du ministère de l'Intérieur
# 2                  Terrain en friche
# 3                 Bâtiment technique
# 4                   Dépôt d'archives
#
#                         designation_batiment_terrain dept  \
# 0                  biens du ministère de l'Intérieur   2B
# 1                  biens du ministère de l'Intérieur   62
# 2                                      MIN de Rungis   94
# 3                  GENDARMERIE  DE SAINT GENIS LAVAL   69
# 4  ARCHIVES JUSTICE CALVADOS (pré-archivage judic...   14
#
#                    adresse code_postal              ville    pays  \
# 0                     None        None               None  France
# 1                     None        None               None  France
# 2  LD LA BUTTE DE CHEVILLY       94260            Fresnes  France
# 3       92 Avenue MAL FOCH       69000  SAINT-GENIS-LAVAL  France
# 4       R NICEPHORE NIEPCE       14120         Mondeville  France
#
#                                            ministere date_inventaire
# 0              Intérieur, Outre-mer et Collec. terr.         2014-03
# 1  Intérieur - Outre-mer - Collectivités territor...         2015-10
# 2                       Services du Premier ministre         2014-03
# 3                                     France Domaine         2013-05
# 4                                            Justice         2017-12

# %%
# Informations générales sur le DataFrame 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   region                        10000 non-null  object
#  1   ue                            9703 non-null   object
#  2   id                            10000 non-null  object
#  3   type                          10000 non-null  object
#  4   fonction                      10000 non-null  object
#  5   designation_batiment_terrain  10000 non-null  object
#  6   dept                          9998 non-null   object
#  7   adresse                       6712 non-null   object
#  8   code_postal                   6985 non-null   object
#  9   ville                         6972 non-null   object
#  10  pays                          10000 non-null  object
#  11  ministere                     10000 non-null  object
#  12  date_inventaire               10000 non-null  object
# dtypes: object(13)
# memory usage: 1015.8+ KB

# %%
# Statistiques descriptives pour les données numériques
df.describe()
# Out:
#                region      ue             id            type  \
# count           10000    9703          10000           10000
# unique             25    5110           9041              18
# top     ILE DE France  110056  IG00100014766  Espace naturel
# freq             1171      54              4            3887
#
#                                  fonction       designation_batiment_terrain  \
# count                               10000                              10000
# unique                                107                               5515
# top     biens du ministère de l'Intérieur  biens du ministère de l'Intérieur
# freq                                 2989                               2989
#
#         dept      adresse code_postal             ville    pays  \
# count   9998         6712        6985              6972   10000
# unique   110         5697        2310              3775      91
# top       13  LD LE BOURG       85460  La Faute-sur-Mer  France
# freq     326           20         127                54    9823
#
#                                                 ministere date_inventaire
# count                                               10000           10000
# unique                                                 46               6
# top     Ecologie - Développement durable - Energie - A...         2013-05
# freq                                                 2518            1881

# %%
# Dimensions du DataFrame 
print(f"Nombre de lignes : {df.shape[0]}")
print(f"Nombre de colonnes : {df.shape[1]}")
# Out:
# Nombre de lignes : 10000
# Nombre de colonnes : 13
